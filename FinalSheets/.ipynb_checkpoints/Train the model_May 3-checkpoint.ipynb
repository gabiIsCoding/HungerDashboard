# %% [markdown]
# # Regression Model

# %% [markdown]
# ## Load Data

# %%
# %autosave 20

#basic library
import pandas as pd
import numpy as np
import collections
from collections import defaultdict


#model training
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# visulization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# Data statistics
from scipy import stats



# print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# Autosaving every 20 seconds

# %%
df = pd.read_excel('databaseForFunction.xlsx', index_col=0)

# %%
df.head()
# Out:
#         State   County  Year  Month  PDensity  Population  SNAP_Applications  \
# 0  California  Alameda  2019      1    1898.5     1559308               5515
# 1  California  Alameda  2019      2    1898.5     1559308               4478
# 2  California  Alameda  2019      3    1898.5     1559308               5041
# 3  California  Alameda  2019      4    1898.5     1559308               5253
# 4  California  Alameda  2019      5    1898.5     1559308               8074
#
#    numberOfWorkers  numberOfDisaster  google_calfresh  google_food_bank  \
# 0               45                 0            24.00             28.75
# 1              397                 0            27.25             27.75
# 2              191                 0            19.60             23.20
# 3              808                 0            23.25             22.50
# 4              502                 0            35.00             26.75
#
#    google_food_pantry  google_food_stamps  google_supplemental  google_snap  \
# 0               38.00               55.50                54.50          0.0
# 1               38.75               31.25                36.75          0.0
# 2               33.80               31.80                35.20          0.0
# 3               35.50               22.00                29.25          0.0
# 4               31.50               29.50                31.25          0.0
#
#    date_time last_date_time  last_snap  last_worker  last_disaster  \
# 0 2019-01-01     2018-12-01          0            0              0
# 1 2019-02-01     2019-01-01       5515           45              0
# 2 2019-03-01     2019-02-01       4478          397              0
# 3 2019-04-01     2019-03-01       5041          191              0
# 4 2019-05-01     2019-04-01       5253          808              0
#
#    last_google_calfresh  last_google_food_bank  last_google_food_pantry  \
# 0                  0.00                   0.00                     0.00
# 1                 24.00                  28.75                    38.00
# 2                 27.25                  27.75                    38.75
# 3                 19.60                  23.20                    33.80
# 4                 23.25                  22.50                    35.50
#
#    last_google_food_stamps  last_google_supplemental  last_google_snap
# 0                     0.00                      0.00               0.0
# 1                    55.50                     54.50               0.0
# 2                    31.25                     36.75               0.0
# 3                    31.80                     35.20               0.0
# 4                    22.00                     29.25               0.0

# %% [markdown]
# ## Add one more feature - dummy value for state

# %%
# split CA and texas using dummy

# create dummy variables
dummies = pd.get_dummies(df['State'], prefix='State')

# concatenate the dummy variables with the original dataframe
df = pd.concat([df, dummies], axis=1)

# %%
# drop State_Texas since using dummy

df = df.drop(columns='State_Texas')

# %% [markdown]
# ## Add one more feature - difference ratio for snap - May 3, 2023

# %%
df.head()
# Out:
#         State   County  Year  Month  PDensity  Population  SNAP_Applications  \
# 0  California  Alameda  2019      1    1898.5     1559308               5515
# 1  California  Alameda  2019      2    1898.5     1559308               4478
# 2  California  Alameda  2019      3    1898.5     1559308               5041
# 3  California  Alameda  2019      4    1898.5     1559308               5253
# 4  California  Alameda  2019      5    1898.5     1559308               8074
#
#    numberOfWorkers  numberOfDisaster  google_calfresh  google_food_bank  \
# 0               45                 0            24.00             28.75
# 1              397                 0            27.25             27.75
# 2              191                 0            19.60             23.20
# 3              808                 0            23.25             22.50
# 4              502                 0            35.00             26.75
#
#    google_food_pantry  google_food_stamps  google_supplemental  google_snap  \
# 0               38.00               55.50                54.50          0.0
# 1               38.75               31.25                36.75          0.0
# 2               33.80               31.80                35.20          0.0
# 3               35.50               22.00                29.25          0.0
# 4               31.50               29.50                31.25          0.0
#
#    date_time last_date_time  last_snap  last_worker  last_disaster  \
# 0 2019-01-01     2018-12-01          0            0              0
# 1 2019-02-01     2019-01-01       5515           45              0
# 2 2019-03-01     2019-02-01       4478          397              0
# 3 2019-04-01     2019-03-01       5041          191              0
# 4 2019-05-01     2019-04-01       5253          808              0
#
#    last_google_calfresh  last_google_food_bank  last_google_food_pantry  \
# 0                  0.00                   0.00                     0.00
# 1                 24.00                  28.75                    38.00
# 2                 27.25                  27.75                    38.75
# 3                 19.60                  23.20                    33.80
# 4                 23.25                  22.50                    35.50
#
#    last_google_food_stamps  last_google_supplemental  last_google_snap  \
# 0                     0.00                      0.00               0.0
# 1                    55.50                     54.50               0.0
# 2                    31.25                     36.75               0.0
# 3                    31.80                     35.20               0.0
# 4                    22.00                     29.25               0.0
#
#    State_California
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
# drop rows whose last_snap is 0

# Drop rows with 0 in column'snap_change_ratio'
df = df.drop(df.loc[(df['last_snap'] == 0)].index)

# %%
df['snap_per_capita'] = round((df.SNAP_Applications / df.last_snap),3)

# %%
df.head()
# Out:
#         State   County  Year  Month  PDensity  Population  SNAP_Applications  \
# 1  California  Alameda  2019      2    1898.5     1559308               4478
# 2  California  Alameda  2019      3    1898.5     1559308               5041
# 3  California  Alameda  2019      4    1898.5     1559308               5253
# 4  California  Alameda  2019      5    1898.5     1559308               8074
# 5  California  Alameda  2019      6    1898.5     1559308              10955
#
#    numberOfWorkers  numberOfDisaster  google_calfresh  google_food_bank  \
# 1              397                 0            27.25             27.75
# 2              191                 0            19.60             23.20
# 3              808                 0            23.25             22.50
# 4              502                 0            35.00             26.75
# 5             1628                 0            35.20             22.00
#
#    google_food_pantry  google_food_stamps  google_supplemental  google_snap  \
# 1               38.75               31.25                36.75          0.0
# 2               33.80               31.80                35.20          0.0
# 3               35.50               22.00                29.25          0.0
# 4               31.50               29.50                31.25          0.0
# 5               32.20               36.00                35.20          0.0
#
#    date_time last_date_time  last_snap  last_worker  last_disaster  \
# 1 2019-02-01     2019-01-01       5515           45              0
# 2 2019-03-01     2019-02-01       4478          397              0
# 3 2019-04-01     2019-03-01       5041          191              0
# 4 2019-05-01     2019-04-01       5253          808              0
# 5 2019-06-01     2019-05-01       8074          502              0
#
#    last_google_calfresh  last_google_food_bank  last_google_food_pantry  \
# 1                 24.00                  28.75                    38.00
# 2                 27.25                  27.75                    38.75
# 3                 19.60                  23.20                    33.80
# 4                 23.25                  22.50                    35.50
# 5                 35.00                  26.75                    31.50
#
#    last_google_food_stamps  last_google_supplemental  last_google_snap  \
# 1                    55.50                     54.50               0.0
# 2                    31.25                     36.75               0.0
# 3                    31.80                     35.20               0.0
# 4                    22.00                     29.25               0.0
# 5                    29.50                     31.25               0.0
#
#    State_California  snap_per_capita
# 1                 1            0.812
# 2                 1            1.126
# 3                 1            1.042
# 4                 1            1.537
# 5                 1            1.357

# %%
# calculate the std of snap_change_ratio

df.snap_per_capita.describe()
# Out:
# count    10473.000000
# mean         1.045468
# std          0.407495
# min          0.000000
# 25%          0.835000
# 50%          0.995000
# 75%          1.171000
# max          9.000000
# Name: snap_per_capita, dtype: float64

# %% [markdown]
# ### Flag the colors on the map

# %% [markdown]
# #### 1. For each county, calculate the mean and standard deviation for "snap per capita" across all data we have.

# %%
gp = df.groupby(['State','County'])['snap_per_capita']

# %%
df1 = gp.agg({'mean','std'}).reset_index().rename(columns={'mean':'mean_snap_per_capita',
                                                          'std':'std_snap_per_capita'})

# %%
df1.head()
# Out:
#         State     County  mean_snap_per_capita  std_snap_per_capita
# 0  California    Alameda              0.977613             0.373290
# 1  California     Alpine              1.282029             1.042579
# 2  California     Amador              1.037486             0.285246
# 3  California      Butte              0.983912             0.308496
# 4  California  Calaveras              1.033371             0.278715

# %%
df1['Yellow_flag'] = abs(df1.mean_snap_per_capita + df1.std_snap_per_capita)
df1['Red_flag'] = abs(df1.mean_snap_per_capita + 2*df1.std_snap_per_capita)

# %% [markdown]
# #### 2. Use mean + std dev for yellow and mean + 2*std dev for red but do this for the absolute values calculated by county above.

# %%
# create a dict to lookup yellow and red flag for each county
# (State, County) : [yellow_value, red_value]
import collections

lookup = collections.defaultdict(list)

for i in range(len(df1)):
    state_key = df1.iloc[i,0]
    county_key = df1.iloc[i, 1]
    yellow = df1.iloc[i, -2]
    red = df1.iloc[i, -1]
    lookup[(state_key, county_key)] = [yellow, red]

# %%
df.head()
# Out:
#         State   County  Year  Month  PDensity  Population  SNAP_Applications  \
# 1  California  Alameda  2019      2    1898.5     1559308               4478
# 2  California  Alameda  2019      3    1898.5     1559308               5041
# 3  California  Alameda  2019      4    1898.5     1559308               5253
# 4  California  Alameda  2019      5    1898.5     1559308               8074
# 5  California  Alameda  2019      6    1898.5     1559308              10955
#
#    numberOfWorkers  numberOfDisaster  google_calfresh  google_food_bank  \
# 1              397                 0            27.25             27.75
# 2              191                 0            19.60             23.20
# 3              808                 0            23.25             22.50
# 4              502                 0            35.00             26.75
# 5             1628                 0            35.20             22.00
#
#    google_food_pantry  google_food_stamps  google_supplemental  google_snap  \
# 1               38.75               31.25                36.75          0.0
# 2               33.80               31.80                35.20          0.0
# 3               35.50               22.00                29.25          0.0
# 4               31.50               29.50                31.25          0.0
# 5               32.20               36.00                35.20          0.0
#
#    date_time last_date_time  last_snap  last_worker  last_disaster  \
# 1 2019-02-01     2019-01-01       5515           45              0
# 2 2019-03-01     2019-02-01       4478          397              0
# 3 2019-04-01     2019-03-01       5041          191              0
# 4 2019-05-01     2019-04-01       5253          808              0
# 5 2019-06-01     2019-05-01       8074          502              0
#
#    last_google_calfresh  last_google_food_bank  last_google_food_pantry  \
# 1                 24.00                  28.75                    38.00
# 2                 27.25                  27.75                    38.75
# 3                 19.60                  23.20                    33.80
# 4                 23.25                  22.50                    35.50
# 5                 35.00                  26.75                    31.50
#
#    last_google_food_stamps  last_google_supplemental  last_google_snap  \
# 1                    55.50                     54.50               0.0
# 2                    31.25                     36.75               0.0
# 3                    31.80                     35.20               0.0
# 4                    22.00                     29.25               0.0
# 5                    29.50                     31.25               0.0
#
#    State_California  snap_per_capita
# 1                 1            0.812
# 2                 1            1.126
# 3                 1            1.042
# 4                 1            1.537
# 5                 1            1.357

# %%
# flag county in df by the value in the lookup

# add one empty column for df
df['Flag'] = ''

# fill 'Flag' in df by the value in the lookup
for i in range(len(df)):
    state_key = df.iloc[i,0]
    county_key = df.iloc[i, 1]
    yellow = lookup[(state_key, county_key)][0]
    red = lookup[(state_key, county_key)][1]
    
    # check the value of snap_per_capita; idx = -2 cuz add one new column
    if df.iloc[i, -2] > red:
        df.iloc[i, -1] = 'Red'
    elif (df.iloc[i, -2] <= red) and (df.iloc[i, -2] > yellow):
        df.iloc[i, -1] = 'Yellow'
    else:
        df.iloc[i, -1] = 'Green'

# %%
df.head()
# Out:
#         State   County  Year  Month  PDensity  Population  SNAP_Applications  \
# 1  California  Alameda  2019      2    1898.5     1559308               4478
# 2  California  Alameda  2019      3    1898.5     1559308               5041
# 3  California  Alameda  2019      4    1898.5     1559308               5253
# 4  California  Alameda  2019      5    1898.5     1559308               8074
# 5  California  Alameda  2019      6    1898.5     1559308              10955
#
#    numberOfWorkers  numberOfDisaster  google_calfresh  google_food_bank  \
# 1              397                 0            27.25             27.75
# 2              191                 0            19.60             23.20
# 3              808                 0            23.25             22.50
# 4              502                 0            35.00             26.75
# 5             1628                 0            35.20             22.00
#
#    google_food_pantry  google_food_stamps  google_supplemental  google_snap  \
# 1               38.75               31.25                36.75          0.0
# 2               33.80               31.80                35.20          0.0
# 3               35.50               22.00                29.25          0.0
# 4               31.50               29.50                31.25          0.0
# 5               32.20               36.00                35.20          0.0
#
#    date_time last_date_time  last_snap  last_worker  last_disaster  \
# 1 2019-02-01     2019-01-01       5515           45              0
# 2 2019-03-01     2019-02-01       4478          397              0
# 3 2019-04-01     2019-03-01       5041          191              0
# 4 2019-05-01     2019-04-01       5253          808              0
# 5 2019-06-01     2019-05-01       8074          502              0
#
#    last_google_calfresh  last_google_food_bank  last_google_food_pantry  \
# 1                 24.00                  28.75                    38.00
# 2                 27.25                  27.75                    38.75
# 3                 19.60                  23.20                    33.80
# 4                 23.25                  22.50                    35.50
# 5                 35.00                  26.75                    31.50
#
#    last_google_food_stamps  last_google_supplemental  last_google_snap  \
# 1                    55.50                     54.50               0.0
# 2                    31.25                     36.75               0.0
# 3                    31.80                     35.20               0.0
# 4                    22.00                     29.25               0.0
# 5                    29.50                     31.25               0.0
#
#    State_California  snap_per_capita    Flag
# 1                 1            0.812   Green
# 2                 1            1.126   Green
# 3                 1            1.042   Green
# 4                 1            1.537  Yellow
# 5                 1            1.357  Yellow

# %%
# calculate the frequence of each color

df.groupby('Flag')['Flag'].count()
# Out:
# Flag
# Green     8995
# Red        463
# Yellow    1015
# Name: Flag, dtype: int64

# %%
# check the frequence of each color

flag = df[['Flag']]
plt.hist(flag, alpha = 0.5, color = 'red', ec = 'black')
# Out:
# (array([8995.,    0.,    0.,    0.,    0., 1015.,    0.,    0.,    0.,
#          463.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Create a json file with 8 variables - May 15
#
# - state + county + year + month + snap application number + flag color + fips value

# %%
df.head()
# Out:
#         State   County  Year  Month  PDensity  Population  SNAP_Applications  \
# 1  California  Alameda  2019      2    1898.5     1559308               4478
# 2  California  Alameda  2019      3    1898.5     1559308               5041
# 3  California  Alameda  2019      4    1898.5     1559308               5253
# 4  California  Alameda  2019      5    1898.5     1559308               8074
# 5  California  Alameda  2019      6    1898.5     1559308              10955
#
#    numberOfWorkers  numberOfDisaster  google_calfresh  google_food_bank  \
# 1              397                 0            27.25             27.75
# 2              191                 0            19.60             23.20
# 3              808                 0            23.25             22.50
# 4              502                 0            35.00             26.75
# 5             1628                 0            35.20             22.00
#
#    google_food_pantry  google_food_stamps  google_supplemental  google_snap  \
# 1               38.75               31.25                36.75          0.0
# 2               33.80               31.80                35.20          0.0
# 3               35.50               22.00                29.25          0.0
# 4               31.50               29.50                31.25          0.0
# 5               32.20               36.00                35.20          0.0
#
#    date_time last_date_time  last_snap  last_worker  last_disaster  \
# 1 2019-02-01     2019-01-01       5515           45              0
# 2 2019-03-01     2019-02-01       4478          397              0
# 3 2019-04-01     2019-03-01       5041          191              0
# 4 2019-05-01     2019-04-01       5253          808              0
# 5 2019-06-01     2019-05-01       8074          502              0
#
#    last_google_calfresh  last_google_food_bank  last_google_food_pantry  \
# 1                 24.00                  28.75                    38.00
# 2                 27.25                  27.75                    38.75
# 3                 19.60                  23.20                    33.80
# 4                 23.25                  22.50                    35.50
# 5                 35.00                  26.75                    31.50
#
#    last_google_food_stamps  last_google_supplemental  last_google_snap  \
# 1                    55.50                     54.50               0.0
# 2                    31.25                     36.75               0.0
# 3                    31.80                     35.20               0.0
# 4                    22.00                     29.25               0.0
# 5                    29.50                     31.25               0.0
#
#    State_California  snap_per_capita    Flag
# 1                 1            0.812   Green
# 2                 1            1.126   Green
# 3                 1            1.042   Green
# 4                 1            1.537  Yellow
# 5                 1            1.357  Yellow

# %%
# pick the variables needed

col_need = ['State', 'County', 'Year', 'Month', 'SNAP_Applications', 'Flag']

df_new = df[col_need]

df_new.head()
# Out:
#         State   County  Year  Month  SNAP_Applications    Flag
# 1  California  Alameda  2019      2               4478   Green
# 2  California  Alameda  2019      3               5041   Green
# 3  California  Alameda  2019      4               5253   Green
# 4  California  Alameda  2019      5               8074  Yellow
# 5  California  Alameda  2019      6              10955  Yellow

# %%
df_new.State.unique()
# Out:
# array(['California', 'Texas'], dtype=object)

# %% [markdown]
# ##  Create fip value dictionary for California and Texas

# %% [markdown]
# ### California

# %%
# import the StrinIO function
# from io module
from io import StringIO
import pandas as pd
 
# wrap the string data in StringIO function
StringData = StringIO("""
State,n1,fipsCountyCode,County,n2
CA,06,001,Alameda County,H1
CA,06,003,Alpine County,H1
CA,06,005,Amador County,H1
CA,06,007,Butte County,H1
CA,06,009,Calaveras County,H1
CA,06,011,Colusa County,H1
CA,06,013,Contra Costa County,H1
CA,06,015,Del Norte County,H1
CA,06,017,El Dorado County,H1
CA,06,019,Fresno County,H1
CA,06,021,Glenn County,H1
CA,06,023,Humboldt County,H1
CA,06,025,Imperial County,H1
CA,06,027,Inyo County,H1
CA,06,029,Kern County,H1
CA,06,031,Kings County,H1
CA,06,033,Lake County,H1
CA,06,035,Lassen County,H1
CA,06,037,Los Angeles County,H1
CA,06,039,Madera County,H1
CA,06,041,Marin County,H1
CA,06,043,Mariposa County,H1
CA,06,045,Mendocino County,H1
CA,06,047,Merced County,H1
CA,06,049,Modoc County,H1
CA,06,051,Mono County,H1
CA,06,053,Monterey County,H1
CA,06,055,Napa County,H1
CA,06,057,Nevada County,H1
CA,06,059,Orange County,H1
CA,06,061,Placer County,H1
CA,06,063,Plumas County,H1
CA,06,065,Riverside County,H1
CA,06,067,Sacramento County,H1
CA,06,069,San Benito County,H1
CA,06,071,San Bernardino County,H1
CA,06,073,San Diego County,H1
CA,06,075,San Francisco County,H6
CA,06,077,San Joaquin County,H1
CA,06,079,San Luis Obispo County,H1
CA,06,081,San Mateo County,H1
CA,06,083,Santa Barbara County,H1
CA,06,085,Santa Clara County,H1
CA,06,087,Santa Cruz County,H1
CA,06,089,Shasta County,H1
CA,06,091,Sierra County,H1
CA,06,093,Siskiyou County,H1
CA,06,095,Solano County,H1
CA,06,097,Sonoma County,H1
CA,06,099,Stanislaus County,H1
CA,06,101,Sutter County,H1
CA,06,103,Tehama County,H1
CA,06,105,Trinity County,H1
CA,06,107,Tulare County,H1
CA,06,109,Tuolumne County,H1
CA,06,111,Ventura County,H1
CA,06,113,Yolo County,H1
CA,06,115,Yuba County,H1

    """)
 
# let's read the data using the Pandas
# read_csv() function
df_ca = pd.read_csv(StringData, sep =",", dtype='object')
 
df_ca['fipsValue'] = df_ca.n1 + df_ca.fipsCountyCode
df_ca.head()
# Out:
#   State  n1 fipsCountyCode            County  n2 fipsValue
# 0    CA  06            001    Alameda County  H1     06001
# 1    CA  06            003     Alpine County  H1     06003
# 2    CA  06            005     Amador County  H1     06005
# 3    CA  06            007      Butte County  H1     06007
# 4    CA  06            009  Calaveras County  H1     06009

# %%
# only keep State, County and fipsValue

col = ['State', 'County', 'fipsValue']

df_ca = df_ca[col]

df_ca.head()
# Out:
#   State            County fipsValue
# 0    CA    Alameda County     06001
# 1    CA     Alpine County     06003
# 2    CA     Amador County     06005
# 3    CA      Butte County     06007
# 4    CA  Calaveras County     06009

# %% [markdown]
# ### Texas

# %%
StringData = StringIO("""
State,n1,fipsCountyCode,County,n2
TX,48,001,Anderson County,H1
TX,48,003,Andrews County,H1
TX,48,005,Angelina County,H1
TX,48,007,Aransas County,H1
TX,48,009,Archer County,H1
TX,48,011,Armstrong County,H1
TX,48,013,Atascosa County,H1
TX,48,015,Austin County,H1
TX,48,017,Bailey County,H1
TX,48,019,Bandera County,H1
TX,48,021,Bastrop County,H1
TX,48,023,Baylor County,H1
TX,48,025,Bee County,H1
TX,48,027,Bell County,H1
TX,48,411,San Saba County,H1
TX,48,413,Schleicher County,H1
TX,48,415,Scurry County,H1
TX,48,417,Shackelford County,H1
TX,48,419,Shelby County,H1
TX,48,421,Sherman County,H1
TX,48,423,Smith County,H1
TX,48,425,Somervell County,H1
TX,48,427,Starr County,H1
TX,48,429,Stephens County,H1
TX,48,431,Sterling County,H1
TX,48,433,Stonewall County,H1
TX,48,435,Sutton County,H1
TX,48,437,Swisher County,H1
TX,48,439,Tarrant County,H1
TX,48,441,Taylor County,H1
TX,48,443,Terrell County,H1
TX,48,445,Terry County,H1
TX,48,447,Throckmorton County,H1
TX,48,449,Titus County,H1
TX,48,451,Tom Green County,H1
TX,48,453,Travis County,H1
TX,48,455,Trinity County,H1
TX,48,457,Tyler County,H1
TX,48,459,Upshur County,H1
TX,48,461,Upton County,H1
TX,48,463,Uvalde County,H1
TX,48,465,Val Verde County,H1
TX,48,467,Van Zandt County,H1
TX,48,469,Victoria County,H1
TX,48,471,Walker County,H1
TX,48,473,Waller County,H1
TX,48,475,Ward County,H1
TX,48,477,Washington County,H1
TX,48,479,Webb County,H1
TX,48,481,Wharton County,H1
TX,48,483,Wheeler County,H1
TX,48,485,Wichita County,H1
TX,48,487,Wilbarger County,H1
TX,48,489,Willacy County,H1
TX,48,491,Williamson County,H1
TX,48,493,Wilson County,H1
TX,48,495,Winkler County,H1
TX,48,497,Wise County,H1
TX,48,499,Wood County,H1
TX,48,501,Yoakum County,H1
TX,48,503,Young County,H1
TX,48,505,Zapata County,H1
TX,48,507,Zavala County,H1
    """)
 
# let's read the data using the Pandas
# read_csv() function
df_te = pd.read_csv(StringData, sep =",", dtype='object')
 

df_te['fipsValue'] = df_te.n1 + df_te.fipsCountyCode
df_te.head()
# Out:
#   State  n1 fipsCountyCode           County  n2 fipsValue
# 0    TX  48            001  Anderson County  H1     48001
# 1    TX  48            003   Andrews County  H1     48003
# 2    TX  48            005  Angelina County  H1     48005
# 3    TX  48            007   Aransas County  H1     48007
# 4    TX  48            009    Archer County  H1     48009

# %%
# only keep State, County and fipsValue

col = ['State', 'County', 'fipsValue']

df_te = df_te[col]

df_te.head()
# Out:
#   State           County fipsValue
# 0    TX  Anderson County     48001
# 1    TX   Andrews County     48003
# 2    TX  Angelina County     48005
# 3    TX   Aransas County     48007
# 4    TX    Archer County     48009

# %% [markdown]
# ## Add fipsValue into the df_new dataframe by keys ['State', 'County']

# %%
# make CA and TE to California and Texas

df_ca['State'] = 'California'
df_te['State'] = 'Texas'

df_ca.head()
# Out:
#         State            County fipsValue
# 0  California    Alameda County     06001
# 1  California     Alpine County     06003
# 2  California     Amador County     06005
# 3  California      Butte County     06007
# 4  California  Calaveras County     06009

# %%
df_te.head()
# Out:
#    State           County fipsValue
# 0  Texas  Anderson County     48001
# 1  Texas   Andrews County     48003
# 2  Texas  Angelina County     48005
# 3  Texas   Aransas County     48007
# 4  Texas    Archer County     48009

# %%
# combine df_ca and df_te

df_fips = pd.merge(df_ca, df_te, how='outer')
df_fips.head()
# Out:
#         State            County fipsValue
# 270       Texas        Somervell County     48425
# 271       Texas            Starr County     48427
# 272       Texas         Stephens County     48429
# 273       Texas         Sterling County     48431
# 274       Texas        Stonewall County     48433
# 275       Texas           Sutton County     48435
# 276       Texas          Swisher County     48437
# 277       Texas          Tarrant County     48439
# 278       Texas           Taylor County     48441
# 279       Texas          Terrell County     48443
# 280       Texas            Terry County     48445
# 281       Texas     Throckmorton County     48447
# 282       Texas            Titus County     48449
# 283       Texas        Tom Green County     48451
# 284       Texas           Travis County     48453
# 285       Texas          Trinity County     48455
# 286       Texas            Tyler County     48457
# 287       Texas           Upshur County     48459
# 288       Texas            Upton County     48461
# 289       Texas           Uvalde County     48463
# 290       Texas        Val Verde County     48465
# 291       Texas        Van Zandt County     48467
# 292       Texas         Victoria County     48469
# 293       Texas           Walker County     48471
# 294       Texas           Waller County     48473
# 295       Texas             Ward County     48475
# 296       Texas       Washington County     48477
# 297       Texas             Webb County     48479
# 298       Texas          Wharton County     48481
# 299       Texas          Wheeler County     48483
# 300       Texas          Wichita County     48485
# 301       Texas        Wilbarger County     48487
# 302       Texas          Willacy County     48489
# 303       Texas       Williamson County     48491
# 304       Texas           Wilson County     48493
# 305       Texas          Winkler County     48495
# 306       Texas             Wise County     48497
# 307       Texas             Wood County     48499
# 308       Texas           Yoakum County     48501
# 309       Texas            Young County     48503
# 310       Texas           Zapata County     48505
# 311       Texas           Zavala County     48507

# %%
df_new.head()
# Out:
#         State   County  Year  Month  SNAP_Applications    Flag
# 1  California  Alameda  2019      2               4478   Green
# 2  California  Alameda  2019      3               5041   Green
# 3  California  Alameda  2019      4               5253   Green
# 4  California  Alameda  2019      5               8074  Yellow
# 5  California  Alameda  2019      6              10955  Yellow

# %%
# # test first 
# test = df_new.copy()
# test['County'] = test.County + ' County'

# %%
# pd.merge(test, df_fips, how='left').info()

# %%
# combine df_new and df_fips by left
df_new['County'] = df_new.County + ' County'
df_new = pd.merge(df_new, df_fips, how='left')
# Out:
# /var/folders/gh/67px3m710b74y6c1mwgnkcq40000gn/T/ipykernel_4882/1402877946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['County'] = df_new.County + ' County'

# %%
df_new.head()
# Out:
#         State          County  Year  Month  SNAP_Applications    Flag  \
# 0  California  Alameda County  2019      2               4478   Green
# 1  California  Alameda County  2019      3               5041   Green
# 2  California  Alameda County  2019      4               5253   Green
# 3  California  Alameda County  2019      5               8074  Yellow
# 4  California  Alameda County  2019      6              10955  Yellow
#
#   fipsValue
# 0     06001
# 1     06001
# 2     06001
# 3     06001
# 4     06001

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10473 entries, 0 to 10472
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              10473 non-null  object
#  1   County             10473 non-null  object
#  2   Year               10473 non-null  int64
#  3   Month              10473 non-null  int64
#  4   SNAP_Applications  10473 non-null  int64
#  5   Flag               10473 non-null  object
#  6   fipsValue          10473 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 654.6+ KB

# %%
# Transfer data to the dictionary

df_new = df_new.to_dict(orient='records')

# %%
import json

json_file = 'databaseForFunction.json'

with open(json_file, 'w') as file:
    json.dump(df_new, file)

# %%
# review json file

with open(json_file, 'r') as file:
    data = json.load(file)

# Dump the data to a formatted JSON string
formatted_json = json.dumps(data, indent=4, sort_keys=True)

print(formatted_json)
# Out:
# [
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 4478,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 5041,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 5253,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Yellow",
#         "Month": 5,
#         "SNAP_Applications": 8074,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Yellow",
#         "Month": 6,
#         "SNAP_Applications": 10955,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 8442,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 7459,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 6555,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 6614,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 5294,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 5146,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 6341,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 5234,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 8152,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Yellow",
#         "Month": 4,
#         "SNAP_Applications": 13951,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 9886,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 8340,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 6968,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 7382,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 6218,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 6240,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 6411,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Yellow",
#         "Month": 12,
#         "SNAP_Applications": 9425,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 0,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 6152,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Yellow",
#         "Month": 6,
#         "SNAP_Applications": 9249,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 0,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 10591,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 10372,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 8435,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alameda County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 7427,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06001"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 2,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 5,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 10,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 5,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 5,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Red",
#         "Month": 3,
#         "SNAP_Applications": 15,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 16,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 5,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 5,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 3,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 5,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 9,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 3,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Yellow",
#         "Month": 4,
#         "SNAP_Applications": 8,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 2,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 4,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 7,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 2,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Red",
#         "Month": 10,
#         "SNAP_Applications": 11,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 10,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Alpine County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 8,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06003"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 102,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 129,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 118,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Yellow",
#         "Month": 5,
#         "SNAP_Applications": 167,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 205,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 192,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 159,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 154,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 151,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 132,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 142,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 171,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 131,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 164,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 211,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 149,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 102,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 109,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Yellow",
#         "Month": 8,
#         "SNAP_Applications": 155,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 159,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 141,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 141,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Red",
#         "Month": 12,
#         "SNAP_Applications": 236,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 212,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 158,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 158,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 142,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 99,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Red",
#         "Month": 6,
#         "SNAP_Applications": 190,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 212,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 201,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 245,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 208,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 254,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Amador County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 171,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06005"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 1198,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 1329,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 1382,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Red",
#         "Month": 5,
#         "SNAP_Applications": 2418,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 2406,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 2057,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 2381,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 2020,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 1780,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 1375,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 1492,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 1901,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 1420,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 1841,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 2264,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 1305,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 1195,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 1253,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Yellow",
#         "Month": 8,
#         "SNAP_Applications": 1848,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 1575,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 1422,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 1379,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Yellow",
#         "Month": 12,
#         "SNAP_Applications": 1872,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 1670,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 1600,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 1419,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 1230,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 1148,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Yellow",
#         "Month": 6,
#         "SNAP_Applications": 1790,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 1742,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 0,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 2073,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 1773,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Butte County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 1666,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06007"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 147,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 195,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 190,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Yellow",
#         "Month": 5,
#         "SNAP_Applications": 297,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 286,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 240,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 266,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 212,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 213,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 193,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 199,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 245,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 190,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 267,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 315,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 164,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 167,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 172,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 215,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 166,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 202,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 197,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Yellow",
#         "Month": 12,
#         "SNAP_Applications": 278,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 193,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 207,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 203,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 166,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 164,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Red",
#         "Month": 6,
#         "SNAP_Applications": 314,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 217,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 272,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 295,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 262,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 268,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Calaveras County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 213,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06009"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 80,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 57,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 54,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Red",
#         "Month": 5,
#         "SNAP_Applications": 92,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 119,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 82,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 76,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 69,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 75,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 62,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 69,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 82,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 79,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 63,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Red",
#         "Month": 4,
#         "SNAP_Applications": 123,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 83,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 77,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 63,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 85,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 59,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 58,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Yellow",
#         "Month": 11,
#         "SNAP_Applications": 82,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 95,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 87,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 74,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 81,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 55,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 53,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Red",
#         "Month": 6,
#         "SNAP_Applications": 103,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 80,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 101,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 102,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 102,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 106,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Colusa County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 105,
#         "State": "California",
#         "Year": 2021,
#         "fipsValue": "06011"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 1834,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 2036,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 2277,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Yellow",
#         "Month": 5,
#         "SNAP_Applications": 3384,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Yellow",
#         "Month": 6,
#         "SNAP_Applications": 4863,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 3805,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 3233,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 2848,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 3023,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 2368,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 2444,
#         "State": "California",
#         "Year": 2019,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 2857,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 2459,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 3528,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Red",
#         "Month": 4,
#         "SNAP_Applications": 6337,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 5093,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 3688,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 2957,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 3209,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 2519,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 2375,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 2494,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
#         "Flag": "Yellow",
#         "Month": 12,
#         "SNAP_Applications": 4176,
#         "State": "California",
#         "Year": 2020,
#         "fipsValue": "06013"
#     },
#     {
#         "County": "Contra Costa County",
# ...
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 99,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 124,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 123,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 147,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 175,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 147,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 118,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Young County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 92,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48503"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 87,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 89,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 101,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 123,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 116,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 147,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 107,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 102,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 127,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 106,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 91,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Yellow",
#         "Month": 1,
#         "SNAP_Applications": 128,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 99,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 115,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Red",
#         "Month": 4,
#         "SNAP_Applications": 205,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 213,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 133,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 160,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 122,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 87,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Red",
#         "Month": 10,
#         "SNAP_Applications": 187,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 183,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 164,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 174,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 148,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 214,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 160,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 141,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Yellow",
#         "Month": 6,
#         "SNAP_Applications": 197,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 201,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 175,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 201,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 206,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 119,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zapata County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 92,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48505"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 94,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 3,
#         "SNAP_Applications": 109,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Yellow",
#         "Month": 4,
#         "SNAP_Applications": 152,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 142,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 180,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 138,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 141,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 128,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 163,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 137,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 128,
#         "State": "Texas",
#         "Year": 2019,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 153,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 110,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 147,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Yellow",
#         "Month": 4,
#         "SNAP_Applications": 204,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 217,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 149,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 143,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 145,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 93,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Red",
#         "Month": 10,
#         "SNAP_Applications": 179,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 211,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 177,
#         "State": "Texas",
#         "Year": 2020,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 1,
#         "SNAP_Applications": 180,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 2,
#         "SNAP_Applications": 149,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Yellow",
#         "Month": 3,
#         "SNAP_Applications": 205,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 4,
#         "SNAP_Applications": 161,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 5,
#         "SNAP_Applications": 141,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 6,
#         "SNAP_Applications": 158,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 7,
#         "SNAP_Applications": 194,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 8,
#         "SNAP_Applications": 228,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 9,
#         "SNAP_Applications": 228,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 10,
#         "SNAP_Applications": 182,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 11,
#         "SNAP_Applications": 128,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     },
#     {
#         "County": "Zavala County",
#         "Flag": "Green",
#         "Month": 12,
#         "SNAP_Applications": 103,
#         "State": "Texas",
#         "Year": 2021,
#         "fipsValue": "48507"
#     }
# ]

# %% [markdown]
# ### updated database Apr 28, 2023

# %%
#df.to_excel('databaseForFunction.xlsx')

# %% [markdown]
# ## Choose columns to train
# - use last month date to predict this month's snap applications

# %%
col_keepinmodel = list(df.columns)

# %%
coltomove = ['State','County','Year','Month', 'date_time','last_date_time', \
             'numberOfWorkers', 'numberOfDisaster','google_calfresh',\
             'google_food_bank','google_food_pantry','google_food_stamps',\
             'google_supplemental','google_snap',]

for c in coltomove:
    col_keepinmodel.remove(c)
    
col_keepinmodel

# %%
df = df[col_keepinmodel]

# %%
df.head()

# %% [markdown]
# # Build the Model

# %% [markdown]
# #### 1. check the correlation

# %%
df.corr()['SNAP_Applications']

# %%
X = df.drop(columns=['SNAP_Applications'])
y = df.SNAP_Applications

# %% [markdown]
# #### 2. Result of the linear regression model

# %%
import statsmodels.api as sm
import pandas as pd

# Add constant term to X
X = sm.add_constant(X)

# Fit linear regression model
model = sm.OLS(y, X).fit()

# Print summary of regression results
print(model.summary())

# %% [markdown]
# For question SVD did not converge
#
# https://blog.csdn.net/lijieling123/article/details/112910530

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

# create example data
x = df.snap_change_ratio
y = df.SNAP_Applications

# create scatter plot
plt.scatter(x, y, c='red', alpha=0.5, edgecolors='black')

# add labels and title
plt.xlabel('snap_change_ratio')
plt.ylabel('SNAP_Applications')
plt.title('Title of the scatter plot')

# display the plot
plt.show()

# %%
X.shape

# %% [markdown]
# ### Flag ratio setting

# %%
df.snap_change_ratio.describe()

# %%
min(df.snap_change_ratio)

# %%
max(df.snap_change_ratio)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data = df.snap_change_ratio.values

# Define the bin intervals and count the number of values in each bin
bins = np.arange(-5,5, 10)
counts, _ = np.histogram(data, bins=bins)

# Create a bar chart of the frequency distribution
plt.bar(bins[:-1], counts, width=10)
plt.xticks(bins)
plt.xlabel('Score Range')
plt.ylabel('Frequency')
plt.show()

# %%
X.loc[(X.snap_change_ratio > 0)].shape

# %%
# When snap_change_ratio is > 0, 48.34% of snap application happened.

5274 / 10908

# %%
X.loc[(X.snap_change_ratio > -0.95)].shape

# %%
# When snap_change_ratio is > -0.95, 97.86% of snap application happened.

10675 / 10908

# %%
X.loc[(X.snap_change_ratio > -0.9)].shape

# %%
# When snap_change_ratio is > -0.9, 97.662% of snap application happened.

10653 / 10908

# %%
import matplotlib.pyplot as plt

# create example data
x = df.last_disaster
y = df.SNAP_Applications

# create scatter plot
plt.scatter(x, y, c='red', alpha=0.5, edgecolors='black')

# add labels and title
plt.xlabel('last_disaster')
plt.ylabel('SNAP_Applications')
plt.title('Title of the scatter plot')

# display the plot
plt.show()
